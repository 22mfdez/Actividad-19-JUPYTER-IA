# %% [markdown]
# Python en inteligencia artificial (IA)
# https://aprendeia.com/agrupando-los-datos-con-python/
#
#
# https://www.analyticslane.com/2018/07/06/agrupacion-de-datos-por-fecha-en-pandas/
#
# Con unitsInStock vamos a hacer grupos.
# 0-50 : stock critico
# 51-100: stock normal
# 101-500: stock
#
# RETO: dibuja un gráfico en donde muestres info en base a esos rangos/grupos

# %%
import pandas as pd
import matplotlib.pyplot as plt



productos=pd.read_csv('products.csv')
#print(productos)

bins=[0,50,100,500] #ponemos desde el inicio y los límites de cada rango
grupos=['stock critico', 'stock normal', 'stock']
df=productos[['unitsInStock']]

#hacemos el DatAfRAME
df['unitsInStock']=pd.cut(df['unitsInStock'], bins, grupos)
#print(df['unitsInStock'])

#pintar un gráfico, en este caso, circular
df.unitsInStock.value_counts().plot.pie()
plt.show()
# Out:
# C:\Users\Tecnicos\AppData\Local\Temp\ipykernel_106296\952113234.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unitsInStock']=pd.cut(df['unitsInStock'], bins, grupos)

# %% [markdown]
# Agrupar datos por fechas:

# %%
import datetime
import numpy as np
import pandas as pd

df = pd.DataFrame()
date = [datetime.datetime(2018, 1, 1) + datetime.timedelta(days=x) for x in range(0, 365)]
value = list(np.random.randint(low=0, high=100, size=365))
df['date'] = pd.to_datetime(date)
df.index = df['date']
df['value'] = value #para cada elemento de la lista asigna un date
#print(df['date'])
#print(df['value'])
print(df.resample('Q').mean())

#pintar un gráfico de barras
x=df.groupby(df['date'].dt.quarter).mean()
x.plot.barh()
# Out:
#                 value
# date
# 2018-03-31  51.277778
# 2018-06-30  50.351648
# 2018-09-30  46.793478
# 2018-12-31  50.402174
# <AxesSubplot:ylabel='date'>
